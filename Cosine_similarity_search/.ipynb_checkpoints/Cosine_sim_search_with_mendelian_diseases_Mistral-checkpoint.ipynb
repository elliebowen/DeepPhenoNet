# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx
from scipy.stats import norm
import seaborn as sns
import matplotlib.pyplot as plt
import os
import openai

import pandas as pd
import os
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx
import bokeh
import os
from mistralai.client import MistralClient
import numpy as np
from sklearn.cluster import KMeans
import backoff
import requests 
from mistralai.client import MistralClient

# %%
# Load embeddings file

# input the path to your saved embeddings
path = '/Users/ellenbowen/Desktop/Michigan/Siwo_lab/'
file = str(path) + 'phecode_mistral_embedding.pkl'

embeddings_df = pd.read_pickle(file)

# %%
embeddings_df
# Out:
#       phecode                                          phenotype  \
# 0        8.00                               Intestinal infection
# 1        8.50                                Bacterial enteritis
# 2        8.51                                  Intestinal e.coli
# 3        8.52           Intestinal infection due to C. difficile
# 4        8.60                                    Viral Enteritis
# ...       ...                                                ...
# 1861   994.00                                    Sepsis and SIRS
# 1862   994.10     Systemic inflammatory response syndrome (SIRS)
# 1863   994.20                                             Sepsis
# 1864   994.21                                       Septic shock
# 1865   996.00  Complications peculiar to certain specified pr...
#
#      phecode_exclude_range   sex  rollup  leaf  category_number  \
# 0               001-009.99   NaN       1     0                1
# 1               001-009.99  Both       1     0                1
# 2               001-009.99  Both       1     1                1
# 3               001-009.99  Both       1     1                1
# 4               001-009.99  Both       1     1                1
# ...                    ...   ...     ...   ...              ...
# 1861            994-994.99   NaN       1     0               18
# 1862            994-994.99  Both       1     1               18
# 1863            994-994.99  Both       1     0               18
# 1864            994-994.99  Both       1     1               18
# 1865            996-999.99   NaN       1     0               18
#
#                    category                                         embeddings
# 0       infectious diseases  [-0.052276611328125, 0.03253173828125, 0.04339...
# 1       infectious diseases  [-0.0306549072265625, 0.04034423828125, 0.0299...
# 2       infectious diseases  [-0.027923583984375, 0.00519561767578125, 0.03...
# 3       infectious diseases  [-0.057037353515625, 0.03045654296875, 0.02819...
# 4       infectious diseases  [-0.0260009765625, 0.0225830078125, 0.02340698...
# ...                     ...                                                ...
# 1861  injuries & poisonings  [-0.0364990234375, 0.040496826171875, 0.017440...
# 1862  injuries & poisonings  [-0.025238037109375, 0.024810791015625, 0.0251...
# 1863  injuries & poisonings  [-0.05938720703125, 0.03619384765625, 0.023345...
# 1864  injuries & poisonings  [-0.06304931640625, 0.0281219482421875, 0.0244...
# 1865  injuries & poisonings  [-0.018035888671875, 0.048583984375, 0.0432434...
#
# [1866 rows x 9 columns]

# %%
#define API from global variable
mistral_client = MistralClient(api_key=os.environ.get("MISTRAL_API_KEY"))

# Embed the Phenotype Column for the First Row
def embed_phenotype(phenotype):
    # Get the embedding for the phenotype using Mistral AI
    response = mistral_client.embeddings(model="mistral-embed", input=[phenotype])
    embedding = response.data[0].embedding
    return embedding

# %%
mendelian_dx = ['Nocturnal frontal lobe epilepsy 1',
'Nephrotic syndrome type 7',
'Sulfocysteinuria',
'Charcotte Marie Tooth Disease 2A',
'Spastic Paraplegia 30',
'Factor X deficiency',
'Hemochromatosis',
'Thyroid dyshormonogenesis',
'Familial erythrocytosis 1',
'Spinocerebellar ataxia',
'Interstitial nephritis karyomegalic',
'HARP syndrome',
'Essential thrombocythemia',
'Primary hyperoxaluria type 1',
'Familial cold autoinflammatory syndrome 3',
'Fabrys Disease',
'Batten disease',
'Splice switching antisense oligonucleotides targeting CLN3']

# Create a DataFrame
mendelian_dx_df = pd.DataFrame(mendelian_dx, columns=['disease'])

# %%
# Apply the get_embedding function to each row and create a new column for embeddings
mendelian_dx_df['embeddings'] = mendelian_dx_df['disease'].apply(embed_phenotype)

# %%
# Save the DataFrame to a .pkl file
mendelian_dx_df.to_pickle('mendelian_diseases_mistral_embeddings.pkl')

# %%
import pandas as pd

# Rename the first column in mendelian_dx_df
mendelian_dx_df.rename(columns={"disease": "phenotype"}, inplace=True)

# Concatenate mendelian_dx_df to embeddings_df
combined_df = pd.concat([embeddings_df, mendelian_dx_df], ignore_index=True)

# %%
combined_df
# Out:
#       phecode                                  phenotype  \
# 0        8.00                       Intestinal infection
# 1        8.50                        Bacterial enteritis
# 2        8.51                          Intestinal e.coli
# 3        8.52   Intestinal infection due to C. difficile
# 4        8.60                            Viral Enteritis
# ...       ...                                        ...
# 1877      NaN                              HARP syndrome
# 1878      NaN                  Essential thrombocythemia
# 1879      NaN               Primary hyperoxaluria type 1
# 1880      NaN  Familial cold autoinflammatory syndrome 3
# 1881      NaN                             Fabrys Disease
#
#      phecode_exclude_range   sex  rollup  leaf  category_number  \
# 0               001-009.99   NaN     1.0   0.0              1.0
# 1               001-009.99  Both     1.0   0.0              1.0
# 2               001-009.99  Both     1.0   1.0              1.0
# 3               001-009.99  Both     1.0   1.0              1.0
# 4               001-009.99  Both     1.0   1.0              1.0
# ...                    ...   ...     ...   ...              ...
# 1877                   NaN   NaN     NaN   NaN              NaN
# 1878                   NaN   NaN     NaN   NaN              NaN
# 1879                   NaN   NaN     NaN   NaN              NaN
# 1880                   NaN   NaN     NaN   NaN              NaN
# 1881                   NaN   NaN     NaN   NaN              NaN
#
#                  category                                         embeddings
# 0     infectious diseases  [-0.052276611328125, 0.03253173828125, 0.04339...
# 1     infectious diseases  [-0.0306549072265625, 0.04034423828125, 0.0299...
# 2     infectious diseases  [-0.027923583984375, 0.00519561767578125, 0.03...
# 3     infectious diseases  [-0.057037353515625, 0.03045654296875, 0.02819...
# 4     infectious diseases  [-0.0260009765625, 0.0225830078125, 0.02340698...
# ...                   ...                                                ...
# 1877                  NaN  [-0.032318115234375, 0.03839111328125, 0.04226...
# 1878                  NaN  [-0.0037937164306640625, 0.0257415771484375, 0...
# 1879                  NaN  [-0.01641845703125, 0.033203125, 0.03231811523...
# 1880                  NaN  [-0.0251922607421875, 0.04913330078125, 0.0483...
# 1881                  NaN  [-0.0234222412109375, 0.0027866363525390625, 0...
#
# [1882 rows x 9 columns]

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Ensure embeddings are in the correct format
def parse_embedding(embedding):
    if isinstance(embedding, str):
        return np.array(eval(embedding))
    return np.array(embedding)

combined_df['embeddings'] = combined_df['embeddings'].apply(parse_embedding)
embeddings = np.vstack(combined_df['embeddings'].values)

# Compute the cosine similarity matrix
cosine_sim_matrix = cosine_similarity(embeddings)

# Create a DataFrame for the similarity matrix with phenotype labels
similarity_df = pd.DataFrame(cosine_sim_matrix, index=combined_df['phenotype'], columns=combined_df['phenotype'])

# %%
similarity_df
# Out:
# phenotype                                  Intestinal infection  \
# phenotype
# Intestinal infection                                   1.000000
# Bacterial enteritis                                    0.875448
# Intestinal e.coli                                      0.880210
# Intestinal infection due to C. difficile               0.870328
# Viral Enteritis                                        0.831335
# ...                                                         ...
# HARP syndrome                                          0.691793
# Essential thrombocythemia                              0.727110
# Primary hyperoxaluria type 1                           0.735577
# Familial cold autoinflammatory syndrome 3              0.733371
# Fabrys Disease                                         0.673671
#
# phenotype                                  Bacterial enteritis  \
# phenotype
# Intestinal infection                                  0.875448
# Bacterial enteritis                                   1.000000
# Intestinal e.coli                                     0.836006
# Intestinal infection due to C. difficile              0.790633
# Viral Enteritis                                       0.877623
# ...                                                        ...
# HARP syndrome                                         0.696452
# Essential thrombocythemia                             0.736104
# Primary hyperoxaluria type 1                          0.740324
# Familial cold autoinflammatory syndrome 3             0.741045
# Fabrys Disease                                        0.692390
#
# phenotype                                  Intestinal e.coli  \
# phenotype
# Intestinal infection                                0.880210
# Bacterial enteritis                                 0.836006
# Intestinal e.coli                                   1.000000
# Intestinal infection due to C. difficile            0.844174
# Viral Enteritis                                     0.813176
# ...                                                      ...
# HARP syndrome                                       0.675049
# Essential thrombocythemia                           0.745246
# Primary hyperoxaluria type 1                        0.745975
# Familial cold autoinflammatory syndrome 3           0.737394
# Fabrys Disease                                      0.699932
#
# phenotype                                  Intestinal infection due to C. difficile  \
# phenotype
# Intestinal infection                                                       0.870328
# Bacterial enteritis                                                        0.790633
# Intestinal e.coli                                                          0.844174
# Intestinal infection due to C. difficile                                   1.000000
# Viral Enteritis                                                            0.796395
# ...                                                                             ...
# HARP syndrome                                                              0.677381
# Essential thrombocythemia                                                  0.737590
# Primary hyperoxaluria type 1                                               0.747690
# Familial cold autoinflammatory syndrome 3                                  0.755604
# Fabrys Disease                                                             0.689735
#
# phenotype                                  Viral Enteritis  \
# phenotype
# Intestinal infection                              0.831335
# Bacterial enteritis                               0.877623
# Intestinal e.coli                                 0.813176
# Intestinal infection due to C. difficile          0.796395
# Viral Enteritis                                   1.000000
# ...                                                    ...
# HARP syndrome                                     0.691331
# Essential thrombocythemia                         0.732265
# Primary hyperoxaluria type 1                      0.736611
# Familial cold autoinflammatory syndrome 3         0.764863
# Fabrys Disease                                    0.734501
#
# phenotype                                  Intestinal infection due to protozoa  \
# phenotype
# Intestinal infection                                                   0.918493
# Bacterial enteritis                                                    0.820179
# Intestinal e.coli                                                      0.840039
# Intestinal infection due to C. difficile                               0.873636
# Viral Enteritis                                                        0.807391
# ...                                                                         ...
# HARP syndrome                                                          0.675400
# Essential thrombocythemia                                              0.751029
# Primary hyperoxaluria type 1                                           0.750104
# Familial cold autoinflammatory syndrome 3                              0.744157
# Fabrys Disease                                                         0.687191
#
# phenotype                                  Tuberculosis  \
# phenotype
# Intestinal infection                           0.719506
# Bacterial enteritis                            0.706865
# Intestinal e.coli                              0.708293
# Intestinal infection due to C. difficile       0.712076
# Viral Enteritis                                0.698086
# ...                                                 ...
# HARP syndrome                                  0.699333
# Essential thrombocythemia                      0.734327
# Primary hyperoxaluria type 1                   0.753532
# Familial cold autoinflammatory syndrome 3      0.729141
# Fabrys Disease                                 0.711818
#
# phenotype                                  Diseases due to other mycobacteria  \
# phenotype
# Intestinal infection                                                 0.767741
# Bacterial enteritis                                                  0.757293
# Intestinal e.coli                                                    0.749382
# Intestinal infection due to C. difficile                             0.794075
# Viral Enteritis                                                      0.754354
# ...                                                                       ...
# HARP syndrome                                                        0.714359
# Essential thrombocythemia                                            0.761009
# Primary hyperoxaluria type 1                                         0.788799
# Familial cold autoinflammatory syndrome 3                            0.790480
# Fabrys Disease                                                       0.739082
#
# phenotype                                   Leprosy  Septicemia  ...  \
# phenotype                                                        ...
# Intestinal infection                       0.699176    0.791417  ...
# Bacterial enteritis                        0.694418    0.780266  ...
# Intestinal e.coli                          0.676374    0.763730  ...
# Intestinal infection due to C. difficile   0.685353    0.743847  ...
# Viral Enteritis                            0.690138    0.733144  ...
# ...                                             ...         ...  ...
# HARP syndrome                              0.714023    0.706914  ...
# Essential thrombocythemia                  0.714414    0.752891  ...
# Primary hyperoxaluria type 1               0.723982    0.737884  ...
# Familial cold autoinflammatory syndrome 3  0.721699    0.728997  ...
# Fabrys Disease                             0.717600    0.687210  ...
#
# phenotype                                  Hemochromatosis  \
# phenotype
# Intestinal infection                              0.741729
# Bacterial enteritis                               0.722393
# Intestinal e.coli                                 0.723770
# Intestinal infection due to C. difficile          0.714003
# Viral Enteritis                                   0.704198
# ...                                                    ...
# HARP syndrome                                     0.757002
# Essential thrombocythemia                         0.815665
# Primary hyperoxaluria type 1                      0.799706
# Familial cold autoinflammatory syndrome 3         0.747807
# Fabrys Disease                                    0.757083
#
# phenotype                                  Thyroid dyshormonogenesis  \
# phenotype
# Intestinal infection                                        0.728502
# Bacterial enteritis                                         0.729639
# Intestinal e.coli                                           0.723827
# Intestinal infection due to C. difficile                    0.744637
# Viral Enteritis                                             0.728013
# ...                                                              ...
# HARP syndrome                                               0.754857
# Essential thrombocythemia                                   0.767637
# Primary hyperoxaluria type 1                                0.810441
# Familial cold autoinflammatory syndrome 3                   0.766612
# Fabrys Disease                                              0.753550
#
# phenotype                                  Familial erythrocytosis 1  \
# phenotype
# Intestinal infection                                        0.680031
# Bacterial enteritis                                         0.701511
# Intestinal e.coli                                           0.727614
# Intestinal infection due to C. difficile                    0.707251
# Viral Enteritis                                             0.729854
# ...                                                              ...
# HARP syndrome                                               0.723025
# Essential thrombocythemia                                   0.855516
# Primary hyperoxaluria type 1                                0.806700
# Familial cold autoinflammatory syndrome 3                   0.817025
# Fabrys Disease                                              0.775622
#
# phenotype                                  Spinocerebellar ataxia  \
# phenotype
# Intestinal infection                                     0.722040
# Bacterial enteritis                                      0.717506
# Intestinal e.coli                                        0.714902
# Intestinal infection due to C. difficile                 0.714739
# Viral Enteritis                                          0.688458
# ...                                                           ...
# HARP syndrome                                            0.744792
# Essential thrombocythemia                                0.775087
# Primary hyperoxaluria type 1                             0.779025
# Familial cold autoinflammatory syndrome 3                0.755967
# Fabrys Disease                                           0.751021
#
# phenotype                                  Interstitial nephritis karyomegalic  \
# phenotype
# Intestinal infection                                                  0.711475
# Bacterial enteritis                                                   0.715625
# Intestinal e.coli                                                     0.735758
# Intestinal infection due to C. difficile                              0.715373
# Viral Enteritis                                                       0.724281
# ...                                                                        ...
# HARP syndrome                                                         0.706013
# Essential thrombocythemia                                             0.732031
# Primary hyperoxaluria type 1                                          0.767223
# Familial cold autoinflammatory syndrome 3                             0.748851
# Fabrys Disease                                                        0.719729
#
# phenotype                                  HARP syndrome  \
# phenotype
# Intestinal infection                            0.691793
# Bacterial enteritis                             0.696452
# Intestinal e.coli                               0.675049
# Intestinal infection due to C. difficile        0.677381
# Viral Enteritis                                 0.691331
# ...                                                  ...
# HARP syndrome                                   1.000000
# Essential thrombocythemia                       0.741262
# Primary hyperoxaluria type 1                    0.773366
# Familial cold autoinflammatory syndrome 3       0.790486
# Fabrys Disease                                  0.742041
#
# phenotype                                  Essential thrombocythemia  \
# phenotype
# Intestinal infection                                        0.727110
# Bacterial enteritis                                         0.736104
# Intestinal e.coli                                           0.745246
# Intestinal infection due to C. difficile                    0.737590
# Viral Enteritis                                             0.732265
# ...                                                              ...
# HARP syndrome                                               0.741262
# Essential thrombocythemia                                   1.000000
# Primary hyperoxaluria type 1                                0.781988
# Familial cold autoinflammatory syndrome 3                   0.774267
# Fabrys Disease                                              0.734342
#
# phenotype                                  Primary hyperoxaluria type 1  \
# phenotype
# Intestinal infection                                           0.735577
# Bacterial enteritis                                            0.740324
# Intestinal e.coli                                              0.745975
# Intestinal infection due to C. difficile                       0.747690
# Viral Enteritis                                                0.736611
# ...                                                                 ...
# HARP syndrome                                                  0.773366
# Essential thrombocythemia                                      0.781988
# Primary hyperoxaluria type 1                                   1.000000
# Familial cold autoinflammatory syndrome 3                      0.804006
# Fabrys Disease                                                 0.782881
#
# phenotype                                  Familial cold autoinflammatory syndrome 3  \
# phenotype
# Intestinal infection                                                        0.733371
# Bacterial enteritis                                                         0.741045
# Intestinal e.coli                                                           0.737394
# Intestinal infection due to C. difficile                                    0.755604
# Viral Enteritis                                                             0.764863
# ...                                                                              ...
# HARP syndrome                                                               0.790486
# Essential thrombocythemia                                                   0.774267
# Primary hyperoxaluria type 1                                                0.804006
# Familial cold autoinflammatory syndrome 3                                   1.000000
# Fabrys Disease                                                              0.776051
#
# phenotype                                  Fabrys Disease
# phenotype
# Intestinal infection                             0.673671
# Bacterial enteritis                              0.692390
# Intestinal e.coli                                0.699932
# Intestinal infection due to C. difficile         0.689735
# Viral Enteritis                                  0.734501
# ...                                                   ...
# HARP syndrome                                    0.742041
# Essential thrombocythemia                        0.734342
# Primary hyperoxaluria type 1                     0.782881
# Familial cold autoinflammatory syndrome 3        0.776051
# Fabrys Disease                                   1.000000
#
# [1882 rows x 1882 columns]

# %%
# Save the similarity matrix to a CSV file
similarity_df.to_csv('similarity_matrix_with_mendelian_diseases_phecodes_mistral_embeddings.csv')

# %%
# Plotting the heatmap
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(similarity_df, annot=True, cmap='viridis')
plt.title('Cosine Similarity Matrix Heatmap')
plt.show()

# %%
# def find_similar_phenotypes(df, query, top_n=5):
#     row = df.loc[query]

#     # Sort the values in descending order
#     sorted_row = row.sort_values(ascending=False)

#     # Select the top n values
#     top_values = sorted_row.head(top_n)
#     return top_values

# # Example usage
# query_phenotype = "Intestinal infection"
# top_n = 5
# similar_phenotypes = find_similar_phenotypes(similarity_df, query_phenotype, top_n)
# print(similar_phenotypes)

# %%
import pandas as pd
import difflib

def find_similar_phenotypes(df, query, top_n=5):
    
    print("Search term: " + str(query))
    # Normalize the query to lowercase
    query = query.lower()
    
    # Normalize the dataframe index to lowercase
    normalized_index = df.index.str.lower()
    
    # Find the closest match for the query
    closest_match = difflib.get_close_matches(query, normalized_index, n=1, cutoff=0.6)
    print("Showing results for : " + str(closest_match))
    
    if not closest_match:
        raise ValueError(f"Query phenotype '{query}' not found in the dataframe.")
    
    # Get the actual index of the closest match
    actual_query = df.index[normalized_index == closest_match[0]].tolist()[0]
    
    # Select the row for the query phenotype
    row = df.loc[actual_query]

    # Sort the values in descending order
    sorted_row = row.sort_values(ascending=False)

    # Select the top n values
    top_values = sorted_row.head(top_n)
    
    return top_values

# Example usage
# Assuming similarity_df is your dataframe with similarity scores
query_phenotype = "intestinal infection"
top_n = 10
similar_phenotypes = find_similar_phenotypes(similarity_df, query_phenotype, top_n)
print(similar_phenotypes)
# Out:
# Search term: intestinal infection
# Showing results for : ['intestinal infection']
# phenotype
# Intestinal infection                        1.000000
# Intestinal infection due to protozoa        0.918493
# Intestinal e.coli                           0.880210
# Bacterial enteritis                         0.875448
# Intestinal infection due to C. difficile    0.870328
# Protozoan infection                         0.858841
# Noninfectious gastroenteritis               0.858035
# Impaction of intestine                      0.853622
# Intestinal helminthiases                    0.853619
# Ulceration of intestine                     0.847087
# Name: Intestinal infection, dtype: float64
