# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx
from scipy.stats import norm
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load embeddings file

# input the path to your saved embeddings
path = '/Users/ellenbowen/Desktop/Michigan/Siwo_lab/'
file = str(path) + 'phecode_mistral_embedding.pkl'

embeddings_df = pd.read_pickle(file)

# %%
embeddings_df
# Out:
#       phecode                                          phenotype  \
# 0        8.00                               Intestinal infection
# 1        8.50                                Bacterial enteritis
# 2        8.51                                  Intestinal e.coli
# 3        8.52           Intestinal infection due to C. difficile
# 4        8.60                                    Viral Enteritis
# ...       ...                                                ...
# 1861   994.00                                    Sepsis and SIRS
# 1862   994.10     Systemic inflammatory response syndrome (SIRS)
# 1863   994.20                                             Sepsis
# 1864   994.21                                       Septic shock
# 1865   996.00  Complications peculiar to certain specified pr...
#
#      phecode_exclude_range   sex  rollup  leaf  category_number  \
# 0               001-009.99   NaN       1     0                1
# 1               001-009.99  Both       1     0                1
# 2               001-009.99  Both       1     1                1
# 3               001-009.99  Both       1     1                1
# 4               001-009.99  Both       1     1                1
# ...                    ...   ...     ...   ...              ...
# 1861            994-994.99   NaN       1     0               18
# 1862            994-994.99  Both       1     1               18
# 1863            994-994.99  Both       1     0               18
# 1864            994-994.99  Both       1     1               18
# 1865            996-999.99   NaN       1     0               18
#
#                    category                                         embeddings
# 0       infectious diseases  [-0.052276611328125, 0.03253173828125, 0.04339...
# 1       infectious diseases  [-0.0306549072265625, 0.04034423828125, 0.0299...
# 2       infectious diseases  [-0.027923583984375, 0.00519561767578125, 0.03...
# 3       infectious diseases  [-0.057037353515625, 0.03045654296875, 0.02819...
# 4       infectious diseases  [-0.0260009765625, 0.0225830078125, 0.02340698...
# ...                     ...                                                ...
# 1861  injuries & poisonings  [-0.0364990234375, 0.040496826171875, 0.017440...
# 1862  injuries & poisonings  [-0.025238037109375, 0.024810791015625, 0.0251...
# 1863  injuries & poisonings  [-0.05938720703125, 0.03619384765625, 0.023345...
# 1864  injuries & poisonings  [-0.06304931640625, 0.0281219482421875, 0.0244...
# 1865  injuries & poisonings  [-0.018035888671875, 0.048583984375, 0.0432434...
#
# [1866 rows x 9 columns]

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Ensure embeddings are in the correct format
def parse_embedding(embedding):
    if isinstance(embedding, str):
        return np.array(eval(embedding))
    return np.array(embedding)

embeddings_df['embeddings'] = embeddings_df['embeddings'].apply(parse_embedding)
embeddings = np.vstack(embeddings_df['embeddings'].values)

# Compute the cosine similarity matrix
cosine_sim_matrix = cosine_similarity(embeddings)

# Create a DataFrame for the similarity matrix with phenotype labels
similarity_df = pd.DataFrame(cosine_sim_matrix, index=embeddings_df['phenotype'], columns=embeddings_df['phenotype'])

# %%
similarity_df
# Out:
# phenotype                                           Intestinal infection  \
# phenotype
# Intestinal infection                                            1.000000
# Bacterial enteritis                                             0.875448
# Intestinal e.coli                                               0.880210
# Intestinal infection due to C. difficile                        0.870328
# Viral Enteritis                                                 0.831335
# ...                                                                  ...
# Sepsis and SIRS                                                 0.752149
# Systemic inflammatory response syndrome (SIRS)                  0.743520
# Sepsis                                                          0.768987
# Septic shock                                                    0.778778
# Complications peculiar to certain specified pro...              0.707176
#
# phenotype                                           Bacterial enteritis  \
# phenotype
# Intestinal infection                                           0.875448
# Bacterial enteritis                                            1.000000
# Intestinal e.coli                                              0.836006
# Intestinal infection due to C. difficile                       0.790633
# Viral Enteritis                                                0.877623
# ...                                                                 ...
# Sepsis and SIRS                                                0.758731
# Systemic inflammatory response syndrome (SIRS)                 0.745463
# Sepsis                                                         0.758693
# Septic shock                                                   0.768335
# Complications peculiar to certain specified pro...             0.706199
#
# phenotype                                           Intestinal e.coli  \
# phenotype
# Intestinal infection                                         0.880210
# Bacterial enteritis                                          0.836006
# Intestinal e.coli                                            1.000000
# Intestinal infection due to C. difficile                     0.844174
# Viral Enteritis                                              0.813176
# ...                                                               ...
# Sepsis and SIRS                                              0.748398
# Systemic inflammatory response syndrome (SIRS)               0.746793
# Sepsis                                                       0.749080
# Septic shock                                                 0.762976
# Complications peculiar to certain specified pro...           0.718051
#
# phenotype                                           Intestinal infection due to C. difficile  \
# phenotype
# Intestinal infection                                                                0.870328
# Bacterial enteritis                                                                 0.790633
# Intestinal e.coli                                                                   0.844174
# Intestinal infection due to C. difficile                                            1.000000
# Viral Enteritis                                                                     0.796395
# ...                                                                                      ...
# Sepsis and SIRS                                                                     0.762509
# Systemic inflammatory response syndrome (SIRS)                                      0.767571
# Sepsis                                                                              0.749215
# Septic shock                                                                        0.752783
# Complications peculiar to certain specified pro...                                  0.746468
#
# phenotype                                           Viral Enteritis  \
# phenotype
# Intestinal infection                                       0.831335
# Bacterial enteritis                                        0.877623
# Intestinal e.coli                                          0.813176
# Intestinal infection due to C. difficile                   0.796395
# Viral Enteritis                                            1.000000
# ...                                                             ...
# Sepsis and SIRS                                            0.772259
# Systemic inflammatory response syndrome (SIRS)             0.768759
# Sepsis                                                     0.729933
# Septic shock                                               0.721757
# Complications peculiar to certain specified pro...         0.725567
#
# phenotype                                           Intestinal infection due to protozoa  \
# phenotype
# Intestinal infection                                                            0.918493
# Bacterial enteritis                                                             0.820179
# Intestinal e.coli                                                               0.840039
# Intestinal infection due to C. difficile                                        0.873636
# Viral Enteritis                                                                 0.807391
# ...                                                                                  ...
# Sepsis and SIRS                                                                 0.749859
# Systemic inflammatory response syndrome (SIRS)                                  0.745851
# Sepsis                                                                          0.730781
# Septic shock                                                                    0.744826
# Complications peculiar to certain specified pro...                              0.724724
#
# phenotype                                           Tuberculosis  \
# phenotype
# Intestinal infection                                    0.719506
# Bacterial enteritis                                     0.706865
# Intestinal e.coli                                       0.708293
# Intestinal infection due to C. difficile                0.712076
# Viral Enteritis                                         0.698086
# ...                                                          ...
# Sepsis and SIRS                                         0.733355
# Systemic inflammatory response syndrome (SIRS)          0.733248
# Sepsis                                                  0.804780
# Septic shock                                            0.769512
# Complications peculiar to certain specified pro...      0.717660
#
# phenotype                                           Diseases due to other mycobacteria  \
# phenotype
# Intestinal infection                                                          0.767741
# Bacterial enteritis                                                           0.757293
# Intestinal e.coli                                                             0.749382
# Intestinal infection due to C. difficile                                      0.794075
# Viral Enteritis                                                               0.754354
# ...                                                                                ...
# Sepsis and SIRS                                                               0.781706
# Systemic inflammatory response syndrome (SIRS)                                0.773336
# Sepsis                                                                        0.757652
# Septic shock                                                                  0.753647
# Complications peculiar to certain specified pro...                            0.766432
#
# phenotype                                            Leprosy  Septicemia  ...  \
# phenotype                                                                 ...
# Intestinal infection                                0.699176    0.791417  ...
# Bacterial enteritis                                 0.694418    0.780266  ...
# Intestinal e.coli                                   0.676374    0.763730  ...
# Intestinal infection due to C. difficile            0.685353    0.743847  ...
# Viral Enteritis                                     0.690138    0.733144  ...
# ...                                                      ...         ...  ...
# Sepsis and SIRS                                     0.721587    0.834090  ...
# Systemic inflammatory response syndrome (SIRS)      0.719388    0.794896  ...
# Sepsis                                              0.795573    0.907651  ...
# Septic shock                                        0.746478    0.890962  ...
# Complications peculiar to certain specified pro...  0.702147    0.715100  ...
#
# phenotype                                           Toxic effect of carbon monoxide  \
# phenotype
# Intestinal infection                                                       0.724862
# Bacterial enteritis                                                        0.725572
# Intestinal e.coli                                                          0.745539
# Intestinal infection due to C. difficile                                   0.745743
# Viral Enteritis                                                            0.716835
# ...                                                                             ...
# Sepsis and SIRS                                                            0.766460
# Systemic inflammatory response syndrome (SIRS)                             0.778869
# Sepsis                                                                     0.744031
# Septic shock                                                               0.772859
# Complications peculiar to certain specified pro...                         0.753146
#
# phenotype                                           Toxic effect of other gases, fumes, or vapors  \
# phenotype
# Intestinal infection                                                                     0.728278
# Bacterial enteritis                                                                      0.725608
# Intestinal e.coli                                                                        0.720000
# Intestinal infection due to C. difficile                                                 0.730819
# Viral Enteritis                                                                          0.728974
# ...                                                                                           ...
# Sepsis and SIRS                                                                          0.745532
# Systemic inflammatory response syndrome (SIRS)                                           0.757575
# Sepsis                                                                                   0.748428
# Septic shock                                                                             0.746031
# Complications peculiar to certain specified pro...                                       0.756927
#
# phenotype                                           Toxic effect of noxious substances eaten as food  \
# phenotype
# Intestinal infection                                                                        0.741693
# Bacterial enteritis                                                                         0.751681
# Intestinal e.coli                                                                           0.736055
# Intestinal infection due to C. difficile                                                    0.744478
# Viral Enteritis                                                                             0.735100
# ...                                                                                              ...
# Sepsis and SIRS                                                                             0.731381
# Systemic inflammatory response syndrome (SIRS)                                              0.736654
# Sepsis                                                                                      0.712341
# Septic shock                                                                                0.711987
# Complications peculiar to certain specified pro...                                          0.728802
#
# phenotype                                           Toxic effect of other substances, chiefly nonmedicinal as to source  \
# phenotype
# Intestinal infection                                                                         0.732874
# Bacterial enteritis                                                                          0.726693
# Intestinal e.coli                                                                            0.731420
# Intestinal infection due to C. difficile                                                     0.738245
# Viral Enteritis                                                                              0.722885
# ...                                                                                               ...
# Sepsis and SIRS                                                                              0.728721
# Systemic inflammatory response syndrome (SIRS)                                               0.738894
# Sepsis                                                                                       0.732034
# Septic shock                                                                                 0.732060
# Complications peculiar to certain specified pro...                                           0.740326
#
# phenotype                                           Effects radiation NOS  \
# phenotype
# Intestinal infection                                             0.666351
# Bacterial enteritis                                              0.661859
# Intestinal e.coli                                                0.680987
# Intestinal infection due to C. difficile                         0.667467
# Viral Enteritis                                                  0.657731
# ...                                                                   ...
# Sepsis and SIRS                                                  0.699255
# Systemic inflammatory response syndrome (SIRS)                   0.701733
# Sepsis                                                           0.699133
# Septic shock                                                     0.720648
# Complications peculiar to certain specified pro...               0.687206
#
# phenotype                                           Sepsis and SIRS  \
# phenotype
# Intestinal infection                                       0.752149
# Bacterial enteritis                                        0.758731
# Intestinal e.coli                                          0.748398
# Intestinal infection due to C. difficile                   0.762509
# Viral Enteritis                                            0.772259
# ...                                                             ...
# Sepsis and SIRS                                            1.000000
# Systemic inflammatory response syndrome (SIRS)             0.948527
# Sepsis                                                     0.897442
# Septic shock                                               0.859609
# Complications peculiar to certain specified pro...         0.774028
#
# phenotype                                           Systemic inflammatory response syndrome (SIRS)  \
# phenotype
# Intestinal infection                                                                      0.743520
# Bacterial enteritis                                                                       0.745463
# Intestinal e.coli                                                                         0.746793
# Intestinal infection due to C. difficile                                                  0.767571
# Viral Enteritis                                                                           0.768759
# ...                                                                                            ...
# Sepsis and SIRS                                                                           0.948527
# Systemic inflammatory response syndrome (SIRS)                                            1.000000
# Sepsis                                                                                    0.853348
# Septic shock                                                                              0.835236
# Complications peculiar to certain specified pro...                                        0.780207
#
# phenotype                                             Sepsis  Septic shock  \
# phenotype
# Intestinal infection                                0.768987      0.778778
# Bacterial enteritis                                 0.758693      0.768335
# Intestinal e.coli                                   0.749080      0.762976
# Intestinal infection due to C. difficile            0.749215      0.752783
# Viral Enteritis                                     0.729933      0.721757
# ...                                                      ...           ...
# Sepsis and SIRS                                     0.897442      0.859609
# Systemic inflammatory response syndrome (SIRS)      0.853348      0.835236
# Sepsis                                              1.000000      0.935560
# Septic shock                                        0.935560      1.000000
# Complications peculiar to certain specified pro...  0.745629      0.744312
#
# phenotype                                           Complications peculiar to certain specified procedures
# phenotype
# Intestinal infection                                                                         0.707176
# Bacterial enteritis                                                                          0.706199
# Intestinal e.coli                                                                            0.718051
# Intestinal infection due to C. difficile                                                     0.746468
# Viral Enteritis                                                                              0.725567
# ...                                                                                               ...
# Sepsis and SIRS                                                                              0.774028
# Systemic inflammatory response syndrome (SIRS)                                               0.780207
# Sepsis                                                                                       0.745629
# Septic shock                                                                                 0.744312
# Complications peculiar to certain specified pro...                                           1.000000
#
# [1866 rows x 1866 columns]

# %%
# Save the similarity matrix to a CSV file
similarity_df.to_csv('similarity_matrix_with_phenotypes_mistral.csv')

# %%
# Plotting the heatmap
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(similarity_df, annot=True, cmap='viridis')
plt.title('Cosine Similarity Matrix Heatmap')
plt.show()

# %%
def find_similar_phenotypes(df, query, top_n=5):
    row = df.loc[query]

    # Sort the values in descending order
    sorted_row = row.sort_values(ascending=False)

    # Select the top n values
    top_values = sorted_row.head(top_n)
    return top_values

# Example usage
query_phenotype = "Ulcerative colitis"
top_n = 5
similar_phenotypes = find_similar_phenotypes(similarity_df, query_phenotype, top_n)
print(similar_phenotypes)
# Out:
# phenotype
# Ulcerative colitis              1.000000
# Ulcerative colitis (chronic)    0.923185
# Duodenal ulcer                  0.869946
# Colon cancer                    0.867096
# Ulceration of intestine         0.863266
# Name: Ulcerative colitis, dtype: float64

# %%
def find_similar_phenotypes(df, query, top_n=5):
    row = df.loc[query]
    sorted_row = row.sort_values(ascending=False)
    top_values = sorted_row.head(top_n)
    return top_values

# Example similarity DataFrame (assuming it's already defined as similarity_df)
# similarity_df = pd.DataFrame(...) # Define your similarity_df here

# Example usage
query_phenotype = "Ulcerative colitis"
top_n = 5
similar_phenotypes = find_similar_phenotypes(similarity_df, query_phenotype, top_n)

# Extract the indices of the top similar phenotypes
top_indices = similar_phenotypes.index

# Extract the submatrix for the heatmap
top_similarities = similarity_df.loc[top_indices, top_indices]

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(top_similarities, annot=True, cmap='coolwarm', linewidths=.5)
plt.title(f'Top {top_n} Similar Phenotypes to {query_phenotype}')
plt.show()
