# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx
from scipy.stats import norm
import seaborn as sns
import matplotlib.pyplot as plt
import os
import voyageai
import pandas as pd
import os
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx
import bokeh
import os
import backoff
import numpy as np
from sklearn.cluster import KMeans
import backoff
import requests

# %%
# Load embeddings file

# input the path to your saved embeddings
path = '/Users/ellenbowen/Desktop/Michigan/Siwo_lab/'
file = str(path) + 'phecode_voyage_embedding.pkl'

embeddings_df = pd.read_pickle(file)

# %%
embeddings_df
# Out:
#       phecode                                          phenotype  \
# 0        8.00                               Intestinal infection
# 1        8.50                                Bacterial enteritis
# 2        8.51                                  Intestinal e.coli
# 3        8.52           Intestinal infection due to C. difficile
# 4        8.60                                    Viral Enteritis
# ...       ...                                                ...
# 1861   994.00                                    Sepsis and SIRS
# 1862   994.10     Systemic inflammatory response syndrome (SIRS)
# 1863   994.20                                             Sepsis
# 1864   994.21                                       Septic shock
# 1865   996.00  Complications peculiar to certain specified pr...
#
#      phecode_exclude_range   sex  rollup  leaf  category_number  \
# 0               001-009.99   NaN       1     0                1
# 1               001-009.99  Both       1     0                1
# 2               001-009.99  Both       1     1                1
# 3               001-009.99  Both       1     1                1
# 4               001-009.99  Both       1     1                1
# ...                    ...   ...     ...   ...              ...
# 1861            994-994.99   NaN       1     0               18
# 1862            994-994.99  Both       1     1               18
# 1863            994-994.99  Both       1     0               18
# 1864            994-994.99  Both       1     1               18
# 1865            996-999.99   NaN       1     0               18
#
#                    category                                         embeddings
# 0       infectious diseases  [-0.0158908162266016, 0.035250891000032425, 0....
# 1       infectious diseases  [-0.0012496799463406205, 0.03793037682771683, ...
# 2       infectious diseases  [-0.010055524297058582, 0.047426193952560425, ...
# 3       infectious diseases  [-0.02957858145236969, 0.04090549424290657, 0....
# 4       infectious diseases  [-0.005069051403552294, 0.03614606708288193, 0...
# ...                     ...                                                ...
# 1861  injuries & poisonings  [-0.015241697430610657, 0.029900213703513145, ...
# 1862  injuries & poisonings  [-0.025385240092873573, 0.03399652987718582, 0...
# 1863  injuries & poisonings  [-0.019122302532196045, 0.027068229392170906, ...
# 1864  injuries & poisonings  [-0.03575393557548523, 0.03473980724811554, 0....
# 1865  injuries & poisonings  [-0.032437991350889206, 0.0569794736802578, 0....
#
# [1866 rows x 9 columns]

# %%
vo = voyageai.Client()

def embed_phenotype(phenotype):
    # Get the embedding for the phenotype using Voyage AI
    result = vo.embed(texts=[phenotype], model="voyage-2", input_type="document")
    # Extract embeddings from the EmbeddingsObject
    embedding = result.embeddings[0]
    return embedding

# %%
mendelian_dx = ['Nocturnal frontal lobe epilepsy 1',
'Nephrotic syndrome type 7',
'Sulfocysteinuria',
'Charcotte Marie Tooth Disease 2A',
'Spastic Paraplegia 30',
'Factor X deficiency',
'Hemochromatosis',
'Thyroid dyshormonogenesis',
'Familial erythrocytosis 1',
'Spinocerebellar ataxia',
'Interstitial nephritis karyomegalic',
'HARP syndrome',
'Essential thrombocythemia',
'Primary hyperoxaluria type 1',
'Familial cold autoinflammatory syndrome 3',
'Fabrys Disease']

# Create a DataFrame
mendelian_dx_df = pd.DataFrame(mendelian_dx, columns=['disease'])

# %%
mendelian_dx_df
# Out:
#                                       disease
# 0           Nocturnal frontal lobe epilepsy 1
# 1                   Nephrotic syndrome type 7
# 2                            Sulfocysteinuria
# 3            Charcotte Marie Tooth Disease 2A
# 4                       Spastic Paraplegia 30
# 5                         Factor X deficiency
# 6                             Hemochromatosis
# 7                   Thyroid dyshormonogenesis
# 8                   Familial erythrocytosis 1
# 9                      Spinocerebellar ataxia
# 10        Interstitial nephritis karyomegalic
# 11                              HARP syndrome
# 12                  Essential thrombocythemia
# 13               Primary hyperoxaluria type 1
# 14  Familial cold autoinflammatory syndrome 3
# 15                             Fabrys Disease

# %%
# Apply the get_embedding function to each row and create a new column for embeddings
mendelian_dx_df['embeddings'] = mendelian_dx_df['disease'].apply(embed_phenotype)

# %%
# Save the DataFrame to a .pkl file
mendelian_dx_df.to_pickle('mendelian_diseases_voyage_embeddings.pkl')

# %%
import pandas as pd

# Rename the first column in mendelian_dx_df
mendelian_dx_df.rename(columns={"disease": "phenotype"}, inplace=True)

# Concatenate mendelian_dx_df to embeddings_df
combined_df = pd.concat([embeddings_df, mendelian_dx_df], ignore_index=True)

# %%
combined_df
# Out:
#       phecode                                  phenotype  \
# 0        8.00                       Intestinal infection
# 1        8.50                        Bacterial enteritis
# 2        8.51                          Intestinal e.coli
# 3        8.52   Intestinal infection due to C. difficile
# 4        8.60                            Viral Enteritis
# ...       ...                                        ...
# 1877      NaN                              HARP syndrome
# 1878      NaN                  Essential thrombocythemia
# 1879      NaN               Primary hyperoxaluria type 1
# 1880      NaN  Familial cold autoinflammatory syndrome 3
# 1881      NaN                             Fabrys Disease
#
#      phecode_exclude_range   sex  rollup  leaf  category_number  \
# 0               001-009.99   NaN     1.0   0.0              1.0
# 1               001-009.99  Both     1.0   0.0              1.0
# 2               001-009.99  Both     1.0   1.0              1.0
# 3               001-009.99  Both     1.0   1.0              1.0
# 4               001-009.99  Both     1.0   1.0              1.0
# ...                    ...   ...     ...   ...              ...
# 1877                   NaN   NaN     NaN   NaN              NaN
# 1878                   NaN   NaN     NaN   NaN              NaN
# 1879                   NaN   NaN     NaN   NaN              NaN
# 1880                   NaN   NaN     NaN   NaN              NaN
# 1881                   NaN   NaN     NaN   NaN              NaN
#
#                  category                                         embeddings
# 0     infectious diseases  [-0.0158908162266016, 0.035250891000032425, 0....
# 1     infectious diseases  [-0.0012496799463406205, 0.03793037682771683, ...
# 2     infectious diseases  [-0.010055524297058582, 0.047426193952560425, ...
# 3     infectious diseases  [-0.02957858145236969, 0.04090549424290657, 0....
# 4     infectious diseases  [-0.005069051403552294, 0.03614606708288193, 0...
# ...                   ...                                                ...
# 1877                  NaN  [-0.032509010285139084, 0.04615749791264534, 0...
# 1878                  NaN  [-0.002349270973354578, 0.03846592828631401, 0...
# 1879                  NaN  [-0.0009210984571836889, 0.025785721838474274,...
# 1880                  NaN  [-0.010404447093605995, 0.025906318798661232, ...
# 1881                  NaN  [-0.009978135116398335, 0.031293027102947235, ...
#
# [1882 rows x 9 columns]

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Ensure embeddings are in the correct format
def parse_embedding(embedding):
    if isinstance(embedding, str):
        return np.array(eval(embedding))
    return np.array(embedding)

combined_df['embeddings'] = combined_df['embeddings'].apply(parse_embedding)
embeddings = np.vstack(combined_df['embeddings'].values)

# Compute the cosine similarity matrix
cosine_sim_matrix = cosine_similarity(embeddings)

# Create a DataFrame for the similarity matrix with phenotype labels
similarity_df = pd.DataFrame(cosine_sim_matrix, index=combined_df['phenotype'], columns=combined_df['phenotype'])

# %%
similarity_df
# Out:
# phenotype                                  Intestinal infection  \
# phenotype
# Intestinal infection                                   1.000000
# Bacterial enteritis                                    0.962288
# Intestinal e.coli                                      0.969029
# Intestinal infection due to C. difficile               0.968908
# Viral Enteritis                                        0.963056
# ...                                                         ...
# HARP syndrome                                          0.889666
# Essential thrombocythemia                              0.870682
# Primary hyperoxaluria type 1                           0.885030
# Familial cold autoinflammatory syndrome 3              0.888255
# Fabrys Disease                                         0.901974
#
# phenotype                                  Bacterial enteritis  \
# phenotype
# Intestinal infection                                  0.962288
# Bacterial enteritis                                   1.000000
# Intestinal e.coli                                     0.951698
# Intestinal infection due to C. difficile              0.945704
# Viral Enteritis                                       0.983047
# ...                                                        ...
# HARP syndrome                                         0.893755
# Essential thrombocythemia                             0.873024
# Primary hyperoxaluria type 1                          0.892473
# Familial cold autoinflammatory syndrome 3             0.899912
# Fabrys Disease                                        0.908545
#
# phenotype                                  Intestinal e.coli  \
# phenotype
# Intestinal infection                                0.969029
# Bacterial enteritis                                 0.951698
# Intestinal e.coli                                   1.000000
# Intestinal infection due to C. difficile            0.948993
# Viral Enteritis                                     0.945185
# ...                                                      ...
# HARP syndrome                                       0.869650
# Essential thrombocythemia                           0.864346
# Primary hyperoxaluria type 1                        0.871694
# Familial cold autoinflammatory syndrome 3           0.872510
# Fabrys Disease                                      0.883565
#
# phenotype                                  Intestinal infection due to C. difficile  \
# phenotype
# Intestinal infection                                                       0.968908
# Bacterial enteritis                                                        0.945704
# Intestinal e.coli                                                          0.948993
# Intestinal infection due to C. difficile                                   1.000000
# Viral Enteritis                                                            0.941412
# ...                                                                             ...
# HARP syndrome                                                              0.875323
# Essential thrombocythemia                                                  0.855835
# Primary hyperoxaluria type 1                                               0.868744
# Familial cold autoinflammatory syndrome 3                                  0.877040
# Fabrys Disease                                                             0.891939
#
# phenotype                                  Viral Enteritis  \
# phenotype
# Intestinal infection                              0.963056
# Bacterial enteritis                               0.983047
# Intestinal e.coli                                 0.945185
# Intestinal infection due to C. difficile          0.941412
# Viral Enteritis                                   1.000000
# ...                                                    ...
# HARP syndrome                                     0.902306
# Essential thrombocythemia                         0.874367
# Primary hyperoxaluria type 1                      0.890364
# Familial cold autoinflammatory syndrome 3         0.910157
# Fabrys Disease                                    0.912054
#
# phenotype                                  Intestinal infection due to protozoa  \
# phenotype
# Intestinal infection                                                   0.974034
# Bacterial enteritis                                                    0.948859
# Intestinal e.coli                                                      0.950339
# Intestinal infection due to C. difficile                               0.954089
# Viral Enteritis                                                        0.940598
# ...                                                                         ...
# HARP syndrome                                                          0.869735
# Essential thrombocythemia                                              0.840847
# Primary hyperoxaluria type 1                                           0.869074
# Familial cold autoinflammatory syndrome 3                              0.868456
# Fabrys Disease                                                         0.880630
#
# phenotype                                  Tuberculosis  \
# phenotype
# Intestinal infection                           0.909554
# Bacterial enteritis                            0.914034
# Intestinal e.coli                              0.896673
# Intestinal infection due to C. difficile       0.887060
# Viral Enteritis                                0.922705
# ...                                                 ...
# HARP syndrome                                  0.892179
# Essential thrombocythemia                      0.885133
# Primary hyperoxaluria type 1                   0.873903
# Familial cold autoinflammatory syndrome 3      0.892192
# Fabrys Disease                                 0.911641
#
# phenotype                                  Diseases due to other mycobacteria  \
# phenotype
# Intestinal infection                                                 0.907474
# Bacterial enteritis                                                  0.921766
# Intestinal e.coli                                                    0.894894
# Intestinal infection due to C. difficile                             0.898548
# Viral Enteritis                                                      0.906386
# ...                                                                       ...
# HARP syndrome                                                        0.860353
# Essential thrombocythemia                                            0.851685
# Primary hyperoxaluria type 1                                         0.862199
# Familial cold autoinflammatory syndrome 3                            0.880851
# Fabrys Disease                                                       0.903058
#
# phenotype                                   Leprosy  Septicemia  ...  \
# phenotype                                                        ...
# Intestinal infection                       0.909978    0.923329  ...
# Bacterial enteritis                        0.907947    0.927417  ...
# Intestinal e.coli                          0.893243    0.913342  ...
# Intestinal infection due to C. difficile   0.885229    0.904156  ...
# Viral Enteritis                            0.919581    0.925476  ...
# ...                                             ...         ...  ...
# HARP syndrome                              0.894218    0.897731  ...
# Essential thrombocythemia                  0.870943    0.910773  ...
# Primary hyperoxaluria type 1               0.876054    0.901539  ...
# Familial cold autoinflammatory syndrome 3  0.884544    0.883687  ...
# Fabrys Disease                             0.902682    0.895081  ...
#
# phenotype                                  Hemochromatosis  \
# phenotype
# Intestinal infection                              0.891272
# Bacterial enteritis                               0.896984
# Intestinal e.coli                                 0.874987
# Intestinal infection due to C. difficile          0.876420
# Viral Enteritis                                   0.902112
# ...                                                    ...
# HARP syndrome                                     0.910648
# Essential thrombocythemia                         0.911061
# Primary hyperoxaluria type 1                      0.897908
# Familial cold autoinflammatory syndrome 3         0.888228
# Fabrys Disease                                    0.906384
#
# phenotype                                  Thyroid dyshormonogenesis  \
# phenotype
# Intestinal infection                                        0.878735
# Bacterial enteritis                                         0.880180
# Intestinal e.coli                                           0.862815
# Intestinal infection due to C. difficile                    0.872200
# Viral Enteritis                                             0.887786
# ...                                                              ...
# HARP syndrome                                               0.893279
# Essential thrombocythemia                                   0.880228
# Primary hyperoxaluria type 1                                0.877836
# Familial cold autoinflammatory syndrome 3                   0.882622
# Fabrys Disease                                              0.897819
#
# phenotype                                  Familial erythrocytosis 1  \
# phenotype
# Intestinal infection                                        0.888593
# Bacterial enteritis                                         0.898555
# Intestinal e.coli                                           0.883735
# Intestinal infection due to C. difficile                    0.878709
# Viral Enteritis                                             0.904371
# ...                                                              ...
# HARP syndrome                                               0.899865
# Essential thrombocythemia                                   0.900582
# Primary hyperoxaluria type 1                                0.899545
# Familial cold autoinflammatory syndrome 3                   0.921362
# Fabrys Disease                                              0.914839
#
# phenotype                                  Spinocerebellar ataxia  \
# phenotype
# Intestinal infection                                     0.870277
# Bacterial enteritis                                      0.877985
# Intestinal e.coli                                        0.858898
# Intestinal infection due to C. difficile                 0.856540
# Viral Enteritis                                          0.882553
# ...                                                           ...
# HARP syndrome                                            0.880226
# Essential thrombocythemia                                0.867052
# Primary hyperoxaluria type 1                             0.871527
# Familial cold autoinflammatory syndrome 3                0.873478
# Fabrys Disease                                           0.879685
#
# phenotype                                  Interstitial nephritis karyomegalic  \
# phenotype
# Intestinal infection                                                  0.908549
# Bacterial enteritis                                                   0.912864
# Intestinal e.coli                                                     0.889914
# Intestinal infection due to C. difficile                              0.894188
# Viral Enteritis                                                       0.913578
# ...                                                                        ...
# HARP syndrome                                                         0.889722
# Essential thrombocythemia                                             0.869083
# Primary hyperoxaluria type 1                                          0.895827
# Familial cold autoinflammatory syndrome 3                             0.891934
# Fabrys Disease                                                        0.890171
#
# phenotype                                  HARP syndrome  \
# phenotype
# Intestinal infection                            0.889666
# Bacterial enteritis                             0.893755
# Intestinal e.coli                               0.869650
# Intestinal infection due to C. difficile        0.875323
# Viral Enteritis                                 0.902306
# ...                                                  ...
# HARP syndrome                                   1.000000
# Essential thrombocythemia                       0.870521
# Primary hyperoxaluria type 1                    0.884059
# Familial cold autoinflammatory syndrome 3       0.886141
# Fabrys Disease                                  0.892389
#
# phenotype                                  Essential thrombocythemia  \
# phenotype
# Intestinal infection                                        0.870682
# Bacterial enteritis                                         0.873024
# Intestinal e.coli                                           0.864346
# Intestinal infection due to C. difficile                    0.855835
# Viral Enteritis                                             0.874367
# ...                                                              ...
# HARP syndrome                                               0.870521
# Essential thrombocythemia                                   1.000000
# Primary hyperoxaluria type 1                                0.876606
# Familial cold autoinflammatory syndrome 3                   0.867069
# Fabrys Disease                                              0.871409
#
# phenotype                                  Primary hyperoxaluria type 1  \
# phenotype
# Intestinal infection                                           0.885030
# Bacterial enteritis                                            0.892473
# Intestinal e.coli                                              0.871694
# Intestinal infection due to C. difficile                       0.868744
# Viral Enteritis                                                0.890364
# ...                                                                 ...
# HARP syndrome                                                  0.884059
# Essential thrombocythemia                                      0.876606
# Primary hyperoxaluria type 1                                   1.000000
# Familial cold autoinflammatory syndrome 3                      0.871848
# Fabrys Disease                                                 0.879041
#
# phenotype                                  Familial cold autoinflammatory syndrome 3  \
# phenotype
# Intestinal infection                                                        0.888255
# Bacterial enteritis                                                         0.899912
# Intestinal e.coli                                                           0.872510
# Intestinal infection due to C. difficile                                    0.877040
# Viral Enteritis                                                             0.910157
# ...                                                                              ...
# HARP syndrome                                                               0.886141
# Essential thrombocythemia                                                   0.867069
# Primary hyperoxaluria type 1                                                0.871848
# Familial cold autoinflammatory syndrome 3                                   1.000000
# Fabrys Disease                                                              0.911404
#
# phenotype                                  Fabrys Disease
# phenotype
# Intestinal infection                             0.901974
# Bacterial enteritis                              0.908545
# Intestinal e.coli                                0.883565
# Intestinal infection due to C. difficile         0.891939
# Viral Enteritis                                  0.912054
# ...                                                   ...
# HARP syndrome                                    0.892389
# Essential thrombocythemia                        0.871409
# Primary hyperoxaluria type 1                     0.879041
# Familial cold autoinflammatory syndrome 3        0.911404
# Fabrys Disease                                   1.000000
#
# [1882 rows x 1882 columns]

# %%
# Save the similarity matrix to a CSV file
similarity_df.to_csv('similarity_matrix_with_mendelian_diseases_phecodes_voyage_embeddings.csv')

# %%
# Plotting the heatmap
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(similarity_df, annot=True, cmap='viridis')
plt.title('Cosine Similarity Matrix Heatmap')
plt.show()

# %%
# def find_similar_phenotypes(df, query, top_n=5):
#     row = df.loc[query]

#     # Sort the values in descending order
#     sorted_row = row.sort_values(ascending=False)

#     # Select the top n values
#     top_values = sorted_row.head(top_n)
#     return top_values

# # Example usage
# query_phenotype = "Intestinal infection"
# top_n = 5
# similar_phenotypes = find_similar_phenotypes(similarity_df, query_phenotype, top_n)
# print(similar_phenotypes)

# %%
import pandas as pd
import difflib

def find_similar_phenotypes(df, query, top_n=5):
    
    print("Search term: " + str(query))
    # Normalize the query to lowercase
    query = query.lower()
    
    # Normalize the dataframe index to lowercase
    normalized_index = df.index.str.lower()
    
    # Find the closest match for the query
    closest_match = difflib.get_close_matches(query, normalized_index, n=1, cutoff=0.6)
    print("Showing results for : " + str(closest_match))
    
    if not closest_match:
        raise ValueError(f"Query phenotype '{query}' not found in the dataframe.")
    
    # Get the actual index of the closest match
    actual_query = df.index[normalized_index == closest_match[0]].tolist()[0]
    
    # Select the row for the query phenotype
    row = df.loc[actual_query]

    # Sort the values in descending order
    sorted_row = row.sort_values(ascending=False)

    # Select the top n values
    top_values = sorted_row.head(top_n)
    
    return top_values

# Example usage
# Assuming similarity_df is your dataframe with similarity scores
query_phenotype = "Fabrys disease"
top_n = 10
similar_phenotypes = find_similar_phenotypes(similarity_df, query_phenotype, top_n)
print(similar_phenotypes)
# Out:
# Search term: Fabrys disease
# Showing results for : ['fabrys disease']
# phenotype
# Fabrys Disease               1.000000
# Graves' disease              0.933616
# Fuchs' dystrophy             0.933529
# Peyronie's disease           0.931939
# Takayasu's disease           0.930117
# Myelofibrosis                0.925752
# Reiter's disease             0.924853
# Von willebrand's disease     0.924330
# Cystic fibrosis              0.923562
# Jakob-Creutzfeldt disease    0.923289
# Name: Fabrys Disease, dtype: float64
