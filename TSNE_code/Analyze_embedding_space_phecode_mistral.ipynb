# %%
import pandas as pd
import os
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx
import bokeh
import os
import openai
from openai import OpenAI
import backoff
import numpy as np
from sklearn.cluster import KMeans
from bokeh.plotting import figure, show, ColumnDataSource, output_file, save
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from bokeh.models import HoverTool
from bokeh.palettes import Category20
import json
import plotly.express as px
import plotly.graph_objects as go
import itertools
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import pickle
import json

# %%
# Load embeddings file

# input the path to your saved embeddings
path = '/Users/ellenbowen/Desktop/Michigan/Siwo_lab/'
file = str(path) + 'phecode_mistral_embedding.pkl'

df = pd.read_pickle(file)

# %%
df
# Out:
#       phecode                                          phenotype  \
# 0        8.00                               Intestinal infection
# 1        8.50                                Bacterial enteritis
# 2        8.51                                  Intestinal e.coli
# 3        8.52           Intestinal infection due to C. difficile
# 4        8.60                                    Viral Enteritis
# ...       ...                                                ...
# 1861   994.00                                    Sepsis and SIRS
# 1862   994.10     Systemic inflammatory response syndrome (SIRS)
# 1863   994.20                                             Sepsis
# 1864   994.21                                       Septic shock
# 1865   996.00  Complications peculiar to certain specified pr...
#
#      phecode_exclude_range   sex  rollup  leaf  category_number  \
# 0               001-009.99   NaN       1     0                1
# 1               001-009.99  Both       1     0                1
# 2               001-009.99  Both       1     1                1
# 3               001-009.99  Both       1     1                1
# 4               001-009.99  Both       1     1                1
# ...                    ...   ...     ...   ...              ...
# 1861            994-994.99   NaN       1     0               18
# 1862            994-994.99  Both       1     1               18
# 1863            994-994.99  Both       1     0               18
# 1864            994-994.99  Both       1     1               18
# 1865            996-999.99   NaN       1     0               18
#
#                    category                                         embeddings
# 0       infectious diseases  [-0.052276611328125, 0.03253173828125, 0.04339...
# 1       infectious diseases  [-0.0306549072265625, 0.04034423828125, 0.0299...
# 2       infectious diseases  [-0.027923583984375, 0.00519561767578125, 0.03...
# 3       infectious diseases  [-0.057037353515625, 0.03045654296875, 0.02819...
# 4       infectious diseases  [-0.0260009765625, 0.0225830078125, 0.02340698...
# ...                     ...                                                ...
# 1861  injuries & poisonings  [-0.0364990234375, 0.040496826171875, 0.017440...
# 1862  injuries & poisonings  [-0.025238037109375, 0.024810791015625, 0.0251...
# 1863  injuries & poisonings  [-0.05938720703125, 0.03619384765625, 0.023345...
# 1864  injuries & poisonings  [-0.06304931640625, 0.0281219482421875, 0.0244...
# 1865  injuries & poisonings  [-0.018035888671875, 0.048583984375, 0.0432434...
#
# [1866 rows x 9 columns]

# %%
# Ensure df is the cleaned version without NaN in 'category'
df_cleaned = df.dropna(subset=['category'])
unique_categories = df_cleaned['category'].unique()
categories = unique_categories

# %% [markdown]
# # Tune tSNE

# %%
# '''
# This code grabs all of the embeddings and then fits them to t-SNE 
# '''

embeddings = np.array(df['embeddings'].tolist())

# %%
# Tune perplexity = 2, 5, 30, 50, 100
perplexity = 30

# Initialize t-SNE
tsne = TSNE(n_components=2, random_state=0, perplexity=perplexity, n_iter=5000)

# Run t-SNE on the embeddings
embedded_vectors = tsne.fit_transform(embeddings)

# %% [markdown]
# # t-SNE static plot

# %%
'''
Create static t-SNE plot using matplotlib with category labels
'''

# Create a figure and axis object with a larger figure size
fig, ax = plt.subplots(figsize=(20, 12))  # Increased figure size

# Use the tab20 colormap for the first 20 categories
palette = plt.get_cmap('tab20')

# Manually define additional distinct, colorblind-friendly colors

custom_colors = [
    '#D9AF6B',  # Tan
    '#829356',  # Olive Green
    '#D16969',  # Soft Red
    '#decbe4',  # Pale Lavender
    '#e5d8bd',  # Pale Sand
    '#fddaec',  # Pale Pink
]
# all_custom_colors = [
#     '#a65628',  # Sienna (reddish-brown)
#     '#984ea3',  # Dark Lavender (purplish-blue)
#     '#6C8EBF',  # Blue-ish
#     '#D9AF6B',  # Tan
#     '#829356',  # Olive Green
#     '#4B4B8F',  # Indigo
#     '#D16969',  # Soft Red
#     '#decbe4',  # Pale Lavender
#     '#ccebc5',  # Pale Green
#     '#ffed6f',  # Pastel Yellow
#     '#e5d8bd',  # Pale Sand
#     '#fddaec',  # Pale Pink
# ]


# Plot each category with a unique color
for i, category in enumerate(unique_categories):
    indices = df['category'] == category
    if i < 20:
        # Use colors from the tab20 colormap
        color = palette(i)
    else:
        # Use the custom colors for categories beyond the 20th
        color = custom_colors[i - 20]
        
    ax.scatter(embedded_vectors[indices, 0], embedded_vectors[indices, 1], 
               color=color, label=category, alpha=0.6, edgecolor='w')

# Customize the plot
ax.set_title('t-SNE Visualization of Phecodes', fontsize=24)
ax.set_xlabel('t-SNE axis 1', fontsize=18)
ax.set_ylabel('t-SNE axis 2', fontsize=18)

# Create a custom legend
legend_elements = [Line2D([0], [0], marker='o', color='w', label=category,
                          markerfacecolor=palette(i) if i < 20 else custom_colors[i - 20], markersize=10)
                   for i, category in enumerate(categories)]

ax.legend(handles=legend_elements, title='Categories', title_fontsize='16', fontsize='14',
          loc='center left', bbox_to_anchor=(1, 0.5))


# Save the figure
plt.savefig('/Users/ellenbowen/Desktop/Michigan/Siwo_lab/tsne_static_visualization_phecodes_mistral.png', bbox_inches='tight', dpi=300)

# Show the plot in a new window
plt.show()

# %% [markdown]
# # Save embeddings with tuned perplexity

# %%
# Save embedded_vectors and tsne model
with open('embedded_vectors_phecode_mistral.pkl', 'wb') as file:
    pickle.dump(embedded_vectors, file)

with open('tsne_model_phecode_mistral.pkl', 'wb') as file:
    pickle.dump(tsne, file)

# %% [markdown]
# # Load tsne and embedded vector

# %%
# # Load the embedded vectors

# with open(str(path) + 'embedded_vectors_phecode_mistral.pkl', 'rb') as file:
#     embedded_vectors = pickle.load(file)

# # If you also need to load the fitted model
# with open(str(path)+'tsne_model_phecode_mistral.pkl', 'rb') as file:
#     tsne = pickle.load(file)

# %% [markdown]
# # Interactive t-SNE plot

# %%
'''
Define a color palette for Plotly that is colorblind friendly based on tab20 and 
also includes 5 extra colors
'''

# Manually defined tab20 colors
tab20_colors = [
    '#1f77b4', '#aec7e8',  # Blue
    '#ff7f0e', '#ffbb78',  # Orange
    '#2ca02c', '#98df8a',  # Green
    '#d62728', '#ff9896',  # Red
    '#9467bd', '#c5b0d5',  # Purple
    '#8c564b', '#c49c94',  # Brown
    '#e377c2', '#f7b6d2',  # Pink
    '#7f7f7f', '#c7c7c7',  # Grey
    '#bcbd22', '#dbdb8d',  # Olive
    '#17becf', '#9edae5'   # Cyan
]

# Custom colors
custom_colors = [
    '#D9AF6B',  # Tan
    '#829356',  # Olive Green
    '#D16969',  # Soft Red
    '#decbe4',  # Pale Lavender
    '#e5d8bd',  # Pale Sand
    '#fddaec'   # Pale Pink
]

# Combine tab20 colors with custom colors
all_colors = tab20_colors + custom_colors

# %%
'''
Make interactive t-SNE using Plotly
'''

# Generate hover text for each point
hover_text = df.apply(lambda row: f"Phecode: {row['phecode']}<br>Phenotype: {row['phenotype']}", axis=1)

fig = go.Figure()

for i, category in enumerate(unique_categories):
    # Select data for each category
    category_data = df[df['category'] == category]
    category_embedded = embedded_vectors[category_data.index]
    
    # Use the combined list of colors for the plot
    color = all_colors[i % len(all_colors)]  # Ensure cycling through the colors if more categories than colors

    # Add a trace for each category with the corresponding color and hover text
    fig.add_trace(go.Scatter(
        x=category_embedded[:, 0],
        y=category_embedded[:, 1],
        mode='markers',
        marker=dict(color=color),  # Use the color from the combined color list
        name=category,  # This name appears in the legend
        text=hover_text[category_data.index],  # Hover text for points in this category
        hoverinfo='text'
    ))

# Customize hover label font size
fig.update_traces(hoverlabel=dict(font_size=12))

# Update the layout for better readability
fig.update_layout(
    title='t-SNE Visualization of Phecodes',
    xaxis_title='t-SNE Dimension 1',
    yaxis_title='t-SNE Dimension 2',
    hovermode='closest',
    legend=dict(x=1, y=1, bgcolor='rgba(255, 255, 255, 0.5)'),  # Adjust legend position if necessary
)

fig.show()
# Out:
# <div>                            <div id="7d98ec7a-5c20-48fb-bf2a-629ecd78734b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d98ec7a-5c20-48fb-bf2a-629ecd78734b")) {                    Plotly.newPlot(                        "7d98ec7a-5c20-48fb-bf2a-629ecd78734b",                        [{"hoverinfo":"text","marker":{"color":"#1f77b4"},"mode":"markers","name":"infectious diseases","text":["Phecode: 8.0\u003cbr\u003ePhenotype: Intestinal infection","Phecode: 8.5\u003cbr\u003ePhenotype: Bacterial enteritis","Phecode: 8.51\u003cbr\u003ePhenotype: Intestinal e.coli","Phecode: 8.52\u003cbr\u003ePhenotype: Intestinal infection due to C. difficile","Phecode: 8.6\u003cbr\u003ePhenotype: Viral Enteritis","Phecode: 8.7\u003cbr\u003ePhenotype: Intestinal infection due to protozoa","Phecode: 10.0\u003cbr\u003ePhenotype: Tuberculosis","Phecode: 31.0\u003cbr\u003ePhenotype: Diseases due to other mycobacteria","Phecode: 31.1\u003cbr\u003ePhenotype: Leprosy","Phecode: 38.0\u003cbr\u003ePhenotype: Septicemia","Phecode: 38.1\u003cbr\u003ePhenotype: Gram negative septicemia","Phecode: 38.2\u003cbr\u003ePhenotype: Gram positive septicemia","Phecode: 38.3\u003cbr\u003ePhenotype: Bacteremia","Phecode: 41.0\u003cbr\u003ePhenotype: Bacterial infection NOS","Phecode: 41.1\u003cbr\u003ePhenotype:
cluster_labels = kmeans.fit_predict(embedded_vectors)

# Now generate the hover text for each point, as before
hover_text = df.apply(lambda row: f"Phecode: {row['phecode']}<br>Phenotype: {row['phenotype']}", axis=1)

# Create a Plotly figure
fig = go.Figure()

# Use a color scale for the clusters
color_scale = px.colors.qualitative.Set3  # You can choose another color scale if you prefer

# Plot each cluster with its own color and hover text
for cluster_id in range(10):
    # Points belonging to the current cluster
    points_in_cluster = embedded_vectors[cluster_labels == cluster_id]
    
    fig.add_trace(go.Scatter(
        x=points_in_cluster[:, 0],
        y=points_in_cluster[:, 1],
        mode='markers',
        marker=dict(
            color=color_scale[cluster_id % len(color_scale)],  # Use the color scale
            size=8,
        ),
        name=f'Cluster {cluster_id}',  # Label each cluster
        text=hover_text[cluster_labels == cluster_id],  # Hover text for points in this cluster
        hoverinfo='text'
    ))

# Customize hover label font size
fig.update_traces(hoverlabel=dict(font_size=12))

# Update the layout for better readability
fig.update_layout(
    title='KMeans t-SNE Visualization of Phecodes',
    xaxis_title='t-SNE Dimension 1',
    yaxis_title='t-SNE Dimension 2',
    hovermode='closest'
)

# Show the figure
fig.show()
# Out:
# /Users/ellenbowen/opt/anaconda3/envs/ehail/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# <div>                            <div id="0ad7be9f-d8aa-4419-9cb8-8c4ad59e88fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ad7be9f-d8aa-4419-9cb8-8c4ad59e88fb")) {                    Plotly.newPlot(                        "0ad7be9f-d8aa-4419-9cb8-8c4ad59e88fb",                        [{"hoverinfo":"text","marker":{"color":"rgb(141,211,199)","size":8},"mode":"markers","name":"Cluster 0","text":["Phecode: 250.14\u003cbr\u003ePhenotype: Type 1 diabetes with neurological manifestations","Phecode: 250.15\u003cbr\u003ePhenotype: Diabetes type 1 with peripheral circulatory disorders","Phecode: 250.24\u003cbr\u003ePhenotype: Type 2 diabetes with neurological manifestations","Phecode: 250.25\u003cbr\u003ePhenotype: Diabetes type 2 with peripheral circulatory disorders","Phecode: 250.6\u003cbr\u003ePhenotype: Polyneuropathy in diabetes","Phecode: 264.3\u003cbr\u003ePhenotype: Delayed milestones","Phecode: 290.0\u003cbr\u003ePhenotype: Delirium dementia and amnestic and other cognitive disorders","Phecode: 290.1\u003cbr\u003ePhenotype: Dementias","Phecode: 290.11\u003cbr\u003ePhenotype: Alzheimer's disease","Phecode: 290.12\u003cbr\u003ePhenotype: Dementia with cerebral degenerations","Phecode: 290.13\u003cbr\u003ePhenotype: Senile dementia","Phecode: 290.16\u003cbr\u003ePhenotype: Vascular dementia","Phecode: 290.2\u003cbr\u003ePhenotype: Delirium due to conditions classified elsewhere","Phecode: 290.3\u003cbr\u003ePhenotype: Other persistent mental disorders due to conditions classified elsewhere","Phecode: 291.0\u003cbr\u003ePhenotype: Other specified nonpsychotic and\u002for transient mental disorders","Phecode: 291.1\u003cbr\u003ePhenotype: Transient mental disorders due to conditions classified elsewhere","Phecode: 291.4\u003cbr\u003ePhenotype: Specific nonpsychotic mental disorders due to brain damage","Phecode: 291.8\u003cbr\u003ePhenotype: Alteration of consciousness","Phecode: 292.0\u003cbr\u003ePhenotype: Neurological disorders","Phecode: 292.1\u003cbr\u003ePhenotype: Aphasia\u002fspeech disturbance","Phecode: 292.11\u003cbr\u003ePhenotype: Aphasia","Phecode: 292.2\u003cbr\u003ePhenotype: Mild cognitive impairment","Phecode: 292.3\u003cbr\u003ePhenotype: Memory loss","Phecode: 292.4\u003cbr\u003ePhenotype: Altered mental status","Phecode: 292.5\u003cbr\u003ePhenotype: Transient alteration of awareness","Phecode: 292.6\u003cbr\u003ePhenotype: Hallucinations","Phecode: 295.0\u003cbr\u003ePhenotype: Schizophrenia and other psychotic disorders","Phecode: 295.1\u003cbr\u003ePhenotype: Schizophrenia","Phecode: 295.2\u003cbr\u003ePhenotype: Paranoid disorders","Phecode: 295.3\u003cbr\u003ePhenotype: Psychosis","Phecode: 296.0\u003cbr\u003ePhenotype: Mood disorders","Phecode: 296.1\u003cbr\u003ePhenotype: Bipolar","Phecode: 296.2\u003cbr\u003ePhenotype: Depression","Phecode: 296.22\u003cbr\u003ePhenotype: Major depressive disorder","Phecode: 297.0\u003cbr\u003ePhenotype: Suicidal ideation or attempt","Phecode: 297.1\u003cbr\u003ePhenotype: Suicidal ideation","Phecode: 300.0\u003cbr\u003ePhenotype: Anxiety disorders","Phecode: 300.1\u003cbr\u003ePhenotype: Anxiety disorder","Phecode: 300.11\u003cbr\u003ePhenotype: Generalized anxiety disorder","Phecode: 300.12\u003cbr\u003ePhenotype: Agorophobia, social phobia, and panic disorder","Phecode: 300.13\u003cbr\u003ePhenotype: Phobia","Phecode: 300.2\u003cbr\u003ePhenotype: Generalized anxiety & phobic disorders","Phecode: 300.3\u003cbr\u003ePhenotype: Obsessive-compulsive disorders","Phecode: 300.4\u003cbr\u003ePhenotype: Dysthymic disorder","Phecode: 300.9\u003cbr\u003ePhenotype: Posttraumatic stress disorder","Phecode: 301.0\u003cbr\u003ePhenotype: Personality disorders","Phecode: 301.1\u003cbr\u003ePhenotype: Schizoid personality disorder","Phecod ...

# %%
# save the plot 
fig.write_html("/Users/ellenbowen/Desktop/Michigan/Siwo_lab/Kmeans_tsne_phecodes_cluster_mistral.html")

# %% [markdown]
# # Kmeans and t-SNE with labels

# %%
'''
Get a list of all the phenotypes within a particular cluster
'''
# Filter the DataFrame to only include rows from the chosen cluster

def cluster_items_dict(df, n_clusters):
    cluster_dict = {}
    for cluster_number in range(n_clusters):
        phenotypes_in_cluster = df[cluster_labels == cluster_number]['phenotype'].tolist()
        cluster_dict[cluster_number] = phenotypes_in_cluster
    
    return cluster_dict

n_clusters = 10
cluster_dict = cluster_items_dict(df, n_clusters)
json_string = json.dumps(cluster_dict)

# save cluster_dict  as a pkl file
with open('cluster_' + str(n_clusters)+'_dict_phecodes_mistral.pkl', 'wb') as file:
    pickle.dump(cluster_dict, file)

# Write the JSON string to a text file
with open('cluster_' + str(n_clusters)+'_dict_phecodes_mistral.txt', 'w') as f:
    f.write(json_string)

# %%
cluster_dict[9]
# Out:
# ['Symptoms concerning nutrition, metabolism, and development',
#  'Family history',
#  'Myeloproliferative disease',
#  'Polycythemia vera',
#  'Multiple myeloma',
#  "Graves' disease",
#  'Hypothyroidism',
#  'Secondary hypothyroidism',
#  'Acquired hypothyroidism',
#  'Iodine hypothyroidism',
#  'Hypothyroidism NOS',
#  'Congenital hypothyroidism',
#  'Thyroiditis',
#  'Thyroiditis, acute and subacute',
#  'Chronic thyroiditis',
#  'Chronic lymphocytic thyroiditis',
#  'Other disorders of thyroid',
#  'Other disorders of pancreatic internal secretion',
#  'Hypoglycemia',
#  'Abnormality of secretion of glucagon or gastrin',
#  'Disorders of parathyroid gland',
#  'Hyperparathyroidism',
#  'Hypoparathyroidism',
#  'Disorders of the pituitary gland and its hypothalamic control',
#  'Pituitary hyperfunction',
#  'Acromegaly and gigantism',
#  'Pituitary hypofunction',
#  'Anterior pituitary disorders',
#  'Pituitary dwarfism',
#  'Other disorders of neurohypophysis',
#  'Diseases of thymus gland',
#  'Disorders of adrenal glands',
#  'Adrenal hyperfunction',
#  "Cushing's syndrome",
#  'Hyperaldosteronism',
#  'Medulloadrenal hyperfunction',
#  'Adrenal hypofunction',
#  'Glucocorticoid deficiency',
#  'Mineralocorticoid deficiency',
#  'Adrenogenital disorders',
#  'Hyperestrogenism',
#  'Iatrogenic endocrine disorders',
#  'Other endocrine disorders',
#  'Polyglandular activity in multiple endocrine adenomatosis',
#  'Protein-calorie malnutrition',
#  'severe protein-calorie malnutrition',
#  'Kwashiorkor',
#  'Nutritional marasmus',
#  'Adult failure to thrive',
#  'Vitamin deficiency',
#  'Vitamin A deficiency',
#  'Vitamin B-complex deficiencies',
#  'Vitamin C deficiencies',
#  'Vitamin D deficiency',
#  'Other nutritional deficiency',
#  'Short stature',
#  'Failure to thrive (childhood)',
#  'Disorders of protein plasma/amino-acid transport and metabolism',
#  'Disturbances of amino-acid transport',
#  'Disturbances of sulphur-bearing amino-acid metabolism',
#  'Phenylketonuria [PKU]',
#  'Disorders of amino-acid metabolism',
#  'Disorders of urea cycle metabolism',
#  'Disorders of plasma protein metabolism',
#  'Polyclonal hypergammaglobulinemia',
#  'Paraproteinemia',
#  'Amyloidosis',
#  'Macroglobulinemia',
#  'Other specified disorders of plasma protein metabolism',
#  'Disorders of carbohydrate transport and metabolism',
#  'Other disorders of carbohydrate transport and metabolism',
#  'Disorders of lipoid metabolism',
#  'Hyperlipidemia',
#  'Hypercholesterolemia',
#  'Hyperglyceridemia',
#  'Mixed hyperlipidemia',
#  'Hyperchylomicronemia',
#  'Unspecified disorder of lipoid metabolism',
#  'Disorders of mineral metabolism',
#  'Disorders of iron metabolism',
#  'Hereditary hemochromatosis',
#  'Disorders of copper metabolism',
#  'Disorders of magnesium metabolism',
#  'Disorders of calcium/phosphorus metabolism',
#  'Hypocalcemia',
#  'Disorders of phosphorus metabolism',
#  'Hypercalcemia',
#  'Disorders of fluid, electrolyte, and acid-base balance',
#  'Electrolyte imbalance',
#  'Hyperpotassemia',
#  'Hypopotassemia',
#  'Acid-base balance disorder',
#  'Acidosis',
#  'Alkalosis',
#  'Other disorders of metabolism',
#  'Disorders of porphyrin metabolism',
#  'Other disorders of purine and pyrimidine metabolism',
#  'Disorders of bilirubin excretion',
#  'Other disorders of lipoid metabolism',
#  'Lipoprotein disorders',
#  'Other deficiencies of circulating enzymes',
#  'Dysmetabolic syndrome X',
#  'Carnitine deficiencies',
#  'Disorders involving the immune mechanism',
#  'Immunity deficiency',
#  'Deficiency of humoral immunity',
#  'Other specified disorders involving the immune mechanism',
#  'Iron deficiency anemias',
#  'Iron deficiency anemias, unspecified or not due to blood loss',
#  'Iron deficiency anemia secondary to blood loss (chronic)',
#  'Other deficiency anemia',
#  'Megaloblastic anemia',
#  'Pernicious anemia',
#  'Other vitamin B12 deficiency anemia',
#  'Folate-deficiency anemia',
#  'Deficiency anemias',
#  'Hereditary hemolytic anemias',
#  'Sickle cell anemia',
#  'Other hemoglobinopathies',
#  'Other hereditary hemolytic anemias',
#  'Acquired hemolytic anemias',
#  'Autoimmune hemolytic anemias',
#  'Non-autoimmune hemolytic anemias',
#  'Hemolytic-uremic syndrome',
#  'Aplastic anemia',
#  'Pancytopenia',
#  'Constitutional aplastic anemia',
#  'Other anemias',
#  'Acute posthemorrhagic anemia',
#  'Anemia of chronic disease',
#  'Anemia in chronic kidney disease',
#  'Anemia in neoplastic disease',
#  'Sideroblastic anemia',
#  'Coagulation defects',
#  'Congenital coagulation defects',
#  "Von willebrand's disease",
#  'Congenital deficiency of other clotting factors (including factor VII)',
#  'Congenital factor VIII disorder',
#  'Coagulation defects complicating pregnancy or postpartum',
#  'Acquired coagulation factor deficiency',
#  'Hemorrhagic disorder due to intrinsic circulating anticoagulants',
#  'Defibrination syndrome',
#  'Other and unspecified coagulation defects',
#  'Hypercoagulable state',
#  'Primary hypercoagulable state',
#  'Abnormal coagulation profile',
#  'Thrombocytopenia',
#  'Primary thrombocytopenia',
#  'Secondary thrombocytopenia',
#  'Qualitative platelet defects',
#  'Diseases of white blood cells',
#  'Neutropenia',
#  'Other diseases of blood and blood-forming organs',
#  'Myelofibrosis',
#  'Personal history of diseases of blood and blood-forming organs',
#  'Diseases of spleen',
#  'Polycythemia, secondary',
#  'Alcoholic liver damage',
#  'Thrombotic microangiopathy',
#  'Chronic liver disease and cirrhosis',
#  'Other chronic nonalcoholic liver disease',
#  'Cirrhosis of liver without mention of alcohol',
#  'Primary biliary cirrhosis',
#  'Liver abscess and sequelae of chronic liver disease',
#  'Other disorders of liver',
#  'Chronic passive congestion of liver',
#  'Hepatomegaly',
#  'Acute and subacute necrosis of liver',
#  'Jaundice (not of newborn)',
#  'Cholelithiasis and cholecystitis',
#  'Cholelithiasis',
#  'Cholelithiasis with acute cholecystitis',
#  'Cholelithiasis with other cholecystitis',
#  'Cholecystitis without cholelithiasis',
#  'Other biliary tract disease',
#  'Cholangitis',
#  'Obstruction of bile duct',
#  'Cholesterolosis of gallbladder',
#  'Other disorders of gallbladder',
#  'Other disorders of biliary tract',
#  'Diseases of pancreas',
#  'Splenomegaly',
#  'Nephritis; nephrosis; renal sclerosis',
#  'Nephrotic syndrome without mention of glomerulonephritis',
#  'Nephritis and nephropathy without mention of glomerulonephritis',
#  'Nephritis and nephropathy in diseases classified elsewhere',
#  'Nephritis and nephropathy with pathological lesion',
#  'Renal sclerosis, NOS',
#  'Renal failure',
#  'Acute renal failure',
#  'Renal dialysis',
#  'End stage renal disease',
#  'Disorders resulting from impaired renal function',
#  'Renal osteodystrophy',
#  'Secondary hyperparathyroidism (of renal origin)',
#  'Anemia during pregnancy',
#  'Hematological disorders of newborn',
#  'Perinatal jaundice',
#  'Chromosomal anomalies and genetic disorders',
#  'Chromosomal anomalies',
#  'Anomalies of endocrine glands, congenital']

# %%
'''
Define cluster names using chatGPT one word summaries of the contents of each cluster
'''

cluster_names = [
    "Neurological",  # Cluster '0' primarily consists of conditions related to neurological and mental health disorders. These include various types of neuropathies, dementias, mood disorders, psychoses, developmental delays, sleep disorders, and other cognitive impairments.
    "Neoplasm",  # Cluster '1' consists predominantly of various types of cancers, affecting multiple body systems such as the oral cavity, respiratory system, digestive tract, skin, and reproductive organs. It also includes related conditions like benign neoplasms, dysplasias, and other malignancy-associated disorders.
    "Musculoskeletal",  # Cluster '2' encompasses a wide range of conditions primarily related to injuries, postoperative complications, musculoskeletal disorders, and various types of pain. It includes both acute and chronic issues such as fractures, infections, arthritis, nerve disorders, and complications from surgical and medical procedures.
    "Metabolic",  # Cluster '3' primarily encompasses metabolic and endocrine disorders, including various forms of diabetes, obesity, and thyroid-related conditions. It also includes related complications such as hypertension, retinopathy, and adverse effects of medications.
    "Signs and symptoms",  # Cluster '4' primarily includes various signs and symptoms associated with different body systems, including abnormalities found in blood tests, imaging studies, and other diagnostic evaluations. It also encompasses various types of leukemias, thyroid disorders, and conditions related to the kidneys and urinary tract.
    "Infectious",  # Cluster '5' primarily encompasses a variety of infections, including bacterial, viral, fungal, and parasitic infections affecting different body systems. It also includes related conditions such as sexually transmitted infections, skin disorders, gastrointestinal diseases, and complications arising from pregnancy and childbirth.
    "Cardiovascular",  # Cluster '6' primarily includes cardiovascular conditions, encompassing various heart diseases, ischemic heart diseases, cardiac dysrhythmias, and vascular disorders. It also covers related neurological issues such as cerebrovascular diseases and intracranial hemorrhages, along with some autoimmune and systemic conditions impacting the cardiovascular system.
    "Infectious-Systemic",  # Cluster '7' includes a variety of infections and infectious diseases, such as viral, bacterial, fungal, and parasitic infections. It also encompasses related conditions like septicemia, hepatitis, and respiratory infections, as well as complications arising from infections, including sepsis and systemic inflammatory response syndrome (SIRS).
    "Congenital",  # Cluster '8' primarily encompasses congenital anomalies and deformities affecting various body systems, including dental, musculoskeletal, gastrointestinal, genitourinary, and cardiovascular systems. It also includes some acquired conditions like skin disorders, hernias, and open wounds.
    "Hepatorenal"  # Cluster '9' primarily includes hepatorenal and metabolic disorders, encompassing conditions affecting the liver, kidneys, endocrine glands, and metabolic processes. It also covers various anemias, nutritional deficiencies, and genetic disorders impacting overall metabolism and organ function.
]

# %%
# Initialize the figure
fig = go.Figure()

# Plot points colored by disease category with hoverable text
for i, category in enumerate(df['category'].unique()):
    category_data = df[df['category'] == category]
    category_embedded = embedded_vectors[category_data.index]
    
    # Generate hover text for each point
    hover_texts = category_data.apply(lambda row: f"Phecode: {row['phecode']}<br>Phenotype: {row['phenotype']}", axis=1)
    
    fig.add_trace(go.Scatter(
        x=category_embedded[:, 0], y=category_embedded[:, 1],
        mode='markers',
        marker=dict(color=all_colors[i % len(all_colors)]),
        name=category,
        text=hover_texts,  # Assign hover text for each point
        hoverinfo='text+name'  # Display hover text and the trace name
    ))
    
# Calculate centroids in the t-SNE space
centroids = kmeans.cluster_centers_

# Annotations for cluster names
annotations = [dict(
    x=centroid[0], y=centroid[1],
    xref="x", yref="y",
    text=cluster_names[i],  # Cluster name as annotation text
    font=dict(color="white", size=12),
    align="center",
    bgcolor="black",  # Black background
    showarrow=True,
    arrowhead=7,
    ax=0,
    ay=-30,  # Adjust this offset to help with positioning
    arrowcolor="black"
) for i, centroid in enumerate(centroids)]

# Customize the layout with a white background and annotations
fig.update_layout(
    title='t-SNE Phecode Visualization with Disease Categories and KMeans Clustering',
    xaxis_title='t-SNE Dimension 1',
    yaxis_title='t-SNE Dimension 2',
    hovermode='closest',
    legend=dict(x=1, y=1, bgcolor='rgba(255, 255, 255, 0.5)'),
    annotations=annotations,  # Add the customized annotations
    plot_bgcolor='white',  # Set the plot background color to white
    paper_bgcolor='white',  # Set the paper (outer) background color to white
    xaxis=dict(
        showgrid=True,  # Show grid lines for the x-axis
        gridcolor='lightgray',  # Color of the grid lines
    ),
    yaxis=dict(
        showgrid=True,  # Show grid lines for the y-axis
        gridcolor='lightgray',  # Color of the grid lines
    )
)

# Show the figure
fig.show()
# Out:
# <div>                            <div id="4253f991-b687-4d9e-932c-65f847770c8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4253f991-b687-4d9e-932c-65f847770c8f")) {                    Plotly.newPlot(                        "4253f991-b687-4d9e-932c-65f847770c8f",                        [{"hoverinfo":"text+name","marker":{"color":"#1f77b4"},"mode":"markers","name":"infectious diseases","text":["Phecode: 8.0\u003cbr\u003ePhenotype: Intestinal infection","Phecode: 8.5\u003cbr\u003ePhenotype: Bacterial enteritis","Phecode: 8.51\u003cbr\u003ePhenotype: Intestinal e.coli","Phecode: 8.52\u003cbr\u003ePhenotype: Intestinal infection due to C. difficile","Phecode: 8.6\u003cbr\u003ePhenotype: Viral Enteritis","Phecode: 8.7\u003cbr\u003ePhenotype: Intestinal infection due to protozoa","Phecode: 10.0\u003cbr\u003ePhenotype: Tuberculosis","Phecode: 31.0\u003cbr\u003ePhenotype: Diseases due to other mycobacteria","Phecode: 31.1\u003cbr\u003ePhenotype: Leprosy","Phecode: 38.0\u003cbr\u003ePhenotype: Septicemia","Phecode: 38.1\u003cbr\u003ePhenotype: Gram negative septicemia","Phecode: 38.2\u003cbr\u003ePhenotype: Gram positive septicemia","Phecode: 38.3\u003cbr\u003ePhenotype: Bacteremia","Phecode:
# %%
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# Initialize the figure
fig = go.Figure()

# Plot points colored by disease category with hoverable text
for i, category in enumerate(df['category'].unique()):
    category_data = df[df['category'] == category]
    category_embedded = embedded_vectors[category_data.index]
    
    # Generate hover text for each point
    hover_texts = category_data.apply(lambda row: f"Phecode: {row['phecode']}<br>Phenotype: {row['phenotype']}", axis=1)
    
    fig.add_trace(go.Scatter(
        x=category_embedded[:, 0], y=category_embedded[:, 1],
        mode='markers',
        marker=dict(color=all_colors[i % len(all_colors)]),
        name=category,
        text=hover_texts,  # Assign hover text for each point
        hoverinfo='text+name',  # Display hover text and the trace name
        selected=dict(marker=dict(size=15)),  # Customize selected points
        unselected=dict(marker=dict(opacity=0.5))  # Customize unselected points
    ))

# Calculate centroids in the t-SNE space
centroids = kmeans.cluster_centers_

# Annotations for cluster names
annotations = [dict(
    x=centroid[0], y=centroid[1],
    xref="x", yref="y",
    text=cluster_names[i],  # Cluster name as annotation text
    font=dict(color="white", size=12),
    align="center",
    bgcolor="black",  # Black background
    showarrow=True,
    arrowhead=7,
    ax=0,
    ay=-30,  # Adjust this offset to help with positioning
    arrowcolor="black"
) for i, centroid in enumerate(centroids)]

# Customize the layout with a white background and annotations
fig.update_layout(
    title='t-SNE Phecode Visualization with Disease Categories and KMeans Clustering',
    xaxis_title='t-SNE Dimension 1',
    yaxis_title='t-SNE Dimension 2',
    hovermode='closest',
    legend=dict(x=1, y=1, bgcolor='rgba(255, 255, 255, 0.5)'),
    annotations=annotations,  # Add the customized annotations
    plot_bgcolor='white',  # Set the plot background color to white
    paper_bgcolor='white',  # Set the paper (outer) background color to white
    xaxis=dict(
        showgrid=True,  # Show grid lines for the x-axis
        gridcolor='lightgray',  # Color of the grid lines
        zeroline=True,  # Show the x=0 line
        zerolinecolor='gray',  # Color of the zero line
        linecolor='black'  # Color of the axis line
    ),
    yaxis=dict(
        showgrid=True,  # Show grid lines for the y-axis
        gridcolor='lightgray',  # Color of the grid lines
        zeroline=True,  # Show the y=0 line
        zerolinecolor='gray',  # Color of the zero line
        linecolor='black'  # Color of the axis line
    )
)

# Show the figure
fig.show()
# Out:
# <div>                            <div id="64b461c4-b0fb-4748-8adf-9687e0d19184" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64b461c4-b0fb-4748-8adf-9687e0d19184")) {                    Plotly.newPlot(                        "64b461c4-b0fb-4748-8adf-9687e0d19184",                        [{"hoverinfo":"text+name","marker":{"color":"#1f77b4"},"mode":"markers","name":"infectious diseases","selected":{"marker":{"size":15}},"text":["Phecode: 8.0\u003cbr\u003ePhenotype: Intestinal infection","Phecode: 8.5\u003cbr\u003ePhenotype: Bacterial enteritis","Phecode: 8.51\u003cbr\u003ePhenotype: Intestinal e.coli","Phecode: 8.52\u003cbr\u003ePhenotype: Intestinal infection due to C. difficile","Phecode: 8.6\u003cbr\u003ePhenotype: Viral Enteritis","Phecode: 8.7\u003cbr\u003ePhenotype: Intestinal infection due to protozoa","Phecode: 10.0\u003cbr\u003ePhenotype: Tuberculosis","Phecode: 31.0\u003cbr\u003ePhenotype: Diseases due to other mycobacteria","Phecode: 31.1\u003cbr\u003ePhenotype: Leprosy","Phecode: 38.0\u003cbr